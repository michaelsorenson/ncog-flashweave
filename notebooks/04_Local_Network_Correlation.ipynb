# %%
import pandas as pd
import numpy as np
import os
import networkx as nx
import sys
sys.path.insert(0, '..')

# %%
import warnings
warnings.filterwarnings('error')

# %% [markdown]
# # Load Data

# %%
eighteenS = pd.read_csv('../data/cleaned/NCOG_18sV4_filtered_asv_count_tax.tsv', sep='\t', index_col=0)
sixteenS = pd.read_csv('../data/cleaned/NCOG_21_16sV4_redo2_filtered_asv_count_tax.tsv', sep='\t', index_col=0)
meta = pd.read_csv('../data/input/NCOG_sample_log_DNA_stvx_meta_2014-2020_mod.tsv', sep='\t', index_col=0)
meta.index = 'X' + meta.index

# %%
meta.columns
# Out:
# Index(['sample_num', 'Cruise', 'Event', 'Order_Occ', 'Sta_ID', 'Cast_Type',
#        'Cardinal_Sta', 'Station_Notes', 'Bottle', 'Assoc_Bottle', 'Depthm',
#        'Bottle_Notes', 'NCOG_DNA', 'NCOG_RNA', 'DNA_VolFilt', 'RNA_VolFilt',
#        'Pump_Speed', 'DNA_RNA_Vol_Notes', 'Filt_Str', 'Filt_End',
#        'Filt_Str_Notes', 'Filt_End_Notes', 'Gly.Sample', 'Sterivex_Notes',
#        'std_18S', 'Date', 'Time', 'DateTime', 'Lat_Dec', 'Lon_Dec', 'Distance',
#        'NoCCSamples', 'Del_Depth', 'CC_Depth', 'T_degC', 'Salnty', 'STheta',
#        'O2ml_L', 'PO4ug', 'SiO3ug', 'NO3ug', 'NH3ug', 'ChlorA', 'Phaeop',
#        'RecInd', 'Code_CCE', 'IntChl', 'IntC14', 'NCDepth', 'MLD_Sigma',
#        'season', 'year', 'sample_type', 'sample_type2', 'siex', 'exclude'],
#       dtype='object')

# %% [markdown]
# ## Get subgraph of the supergraph based on which nodes are present
# I believe this is the implementation done in the Chafron paper to get the degree/strength/weight/density/transitivity X environment variable values correlation matrix

# %%
gph = nx.read_gml('../data/graph/NCOG_network_output_v4.gml')

# %%
def get_average_strength(local_nw_gph):
    edgeweights = nx.get_edge_attributes(local_nw_gph, 'weight')
    edges = pd.DataFrame({
        'Node1': pd.Series(edgeweights.keys(), dtype=object).apply(lambda x: x[0]),
        'Node2': pd.Series(edgeweights.keys(), dtype=object).apply(lambda x: x[1]),
        'Weight': list(edgeweights.values())
    })
    edges_combined = pd.concat([edges, edges.rename({'Node1': 'Node2', 'Node2': 'Node1'}, axis=1)])
    return edges_combined.groupby('Node1')['Weight'].sum().mean()

# %%
all_data = pd.concat([sixteenS, eighteenS], axis=1)
gph_stats = []
for sample, row in all_data.iterrows():
    included_nodes = list(row[row != 0].index)
    sample_gph = gph.subgraph(included_nodes)
    try:
        sample_stats = {
            'Mean degree': pd.Series(np.array(nx.degree(sample_gph))[:,1]).astype(int).mean(),
            'Mean strength': get_average_strength(sample_gph),
            'Mean weight': pd.Series(nx.get_edge_attributes(sample_gph, 'weight').values(), dtype=np.float64).mean(),
            'Edge density': nx.density(sample_gph), # nx.density(local_nw) # Is this edge density? Or a different density?
            'Transitivity': nx.transitivity(sample_gph)
        }
    except:
        print(nx.get_edge_attributes(sample_gph, 'weight'))
        print(row)
        print(included_nodes)
        break
    gph_stats.append(sample_stats)
gph_stats_df = pd.DataFrame(gph_stats, index=all_data.index)

# %%
# create new column with station ID and sample type
meta['Sta_ID_with_sample_type'] = meta['Sta_ID'] + '; ' + meta['sample_type'].astype(str)

# %%
all_data = pd.concat([sixteenS, eighteenS], axis=1)
gph_stats = []
included_stations = []
for station_id in sorted(meta['Sta_ID_with_sample_type'].unique()):
    included_samples = meta[meta['Sta_ID_with_sample_type'] == station_id].index.values
    included_rows = all_data.loc[all_data.index.isin(included_samples)]
    if len(included_rows) == 0:
        print('No matching samples found for station', station_id)
        continue
    included_stations.append(station_id)
    included_nodes = pd.Series(0, index=all_data.columns)
    for sample_id, row in included_rows.iterrows():
        # include every OTU that has an abundance of >0 in any of the samples
        # (prokaryotes and eukaryotes calculated separately)
        prokaryotes = row[row.index.str.contains('potu')]
        eukaryotes = row[row.index.str.contains('eotu')]
        included_potus = prokaryotes[prokaryotes > 0].index
        included_eotus = eukaryotes[eukaryotes > 0].index
        included_nodes.loc[included_potus] = 1
        included_nodes.loc[included_eotus] = 1
    included_nodes = list(included_nodes[included_nodes > 0].index)
    sample_gph = gph.subgraph(included_nodes)
    print('Station', station_id, '\t', len(sample_gph.nodes()), 'Nodes;', len(sample_gph.edges()), 'Edges')
    try:
        sample_stats = {
            'Mean degree': pd.Series(np.array(nx.degree(sample_gph))[:,1]).astype(int).mean(),
            'Mean strength': get_average_strength(sample_gph),
            'Mean weight': pd.Series(nx.get_edge_attributes(sample_gph, 'weight').values(), dtype=np.float64).mean(),
            'Edge density': nx.density(sample_gph), # nx.density(local_nw) # Is this edge density? Or a different density?
            'Transitivity': nx.transitivity(sample_gph)
        }
    except:
        print(nx.get_edge_attributes(sample_gph, 'weight'))
        print(row)
        print(included_nodes)
        break
    gph_stats.append(sample_stats)
gph_stats_df = pd.DataFrame(gph_stats, index=included_stations)
# Out:
# Station 060.0 060.0; DCM 	 761 Nodes; 3512 Edges
# Station 060.0 060.0; Surf 	 686 Nodes; 3181 Edges
# No matching samples found for station 060.0 070.0; DCM
# No matching samples found for station 060.0 070.0; Surf
# Station 060.0 080.0; DCM 	 1070 Nodes; 5810 Edges
# Station 060.0 080.0; Surf 	 833 Nodes; 4169 Edges
# No matching samples found for station 060.0 090.0; Surf
# No matching samples found for station 063.3 052.0; DCM
# No matching samples found for station 063.3 052.0; Surf
# No matching samples found for station 063.3 055.0; DCM
# No matching samples found for station 063.3 055.0; Surf
# No matching samples found for station 063.3 060.0; DCM
# No matching samples found for station 063.3 060.0; Surf
# Station 063.3 070.0; DCM 	 635 Nodes; 2811 Edges
# Station 063.3 070.0; Surf 	 517 Nodes; 2199 Edges
# No matching samples found for station 063.3 080.0; DCM
# No matching samples found for station 063.3 080.0; Surf
# Station 063.3 090.0; DCM 	 889 Nodes; 4222 Edges
# Station 063.3 090.0; Surf 	 405 Nodes; 1655 Edges
# Station 066.7 055.0; DCM 	 465 Nodes; 2224 Edges
# Station 066.7 055.0; Surf 	 378 Nodes; 1803 Edges
# Station 066.7 060.0; DCM 	 641 Nodes; 3052 Edges
# Station 066.7 060.0; Surf 	 548 Nodes; 2505 Edges
# No matching samples found for station 066.7 070.0; Surf
# Station 066.7 080.0; DCM 	 1024 Nodes; 5570 Edges
# Station 066.7 080.0; Surf 	 604 Nodes; 2586 Edges
# No matching samples found for station 066.7 090.0; DCM
# Station 066.7 090.0; Surf 	 690 Nodes; 3058 Edges
# No matching samples found for station 067.0 050.0; nan
# Station 070.0 051.0; DCM 	 737 Nodes; 3420 Edges
# Station 070.0 051.0; Surf 	 667 Nodes; 3114 Edges
# No matching samples found for station 070.0 055.0; Surf
# Station 070.0 070.0; Surf 	 794 Nodes; 4009 Edges
# No matching samples found for station 070.0 080.0; DCM
# Station 070.0 080.0; Surf 	 631 Nodes; 2631 Edges
# Station 070.0 090.0; DCM 	 908 Nodes; 4682 Edges
# Station 070.0 090.0; Surf 	 697 Nodes; 3220 Edges
# Station 073.3 055.0; Surf 	 713 Nodes; 3469 Edges
# Station 073.3 070.0; DCM 	 638 Nodes; 2684 Edges
# Station 073.3 070.0; Surf 	 1061 Nodes; 6287 Edges
# Station 073.3 080.0; DCM 	 881 Nodes; 4482 Edges
# Station 073.3 080.0; Surf 	 568 Nodes; 2637 Edges
# Station 073.3 090.0; DCM 	 1073 Nodes; 5848 Edges
# Station 073.3 090.0; Surf 	 1053 Nodes; 5946 Edges
# Station 076.7 049.0; DCM 	 1004 Nodes; 5560 Edges
# Station 076.7 049.0; Surf 	 1191 Nodes; 7285 Edges
# Station 076.7 051.0; DCM 	 582 Nodes; 2593 Edges
# Station 076.7 051.0; Surf 	 769 Nodes; 4110 Edges
# Station 076.7 055.0; DCM 	 1063 Nodes; 6268 Edges
# Station 076.7 055.0; Surf 	 883 Nodes; 4952 Edges
# Station 076.7 060.0; 170 	 345 Nodes; 1056 Edges
# Station 076.7 060.0; DCM 	 1007 Nodes; 5675 Edges
# Station 076.7 060.0; Surf 	 775 Nodes; 4173 Edges
# Station 076.7 070.0; 170 	 424 Nodes; 1335 Edges
# No matching samples found for station 076.7 070.0; 515
# Station 076.7 070.0; DCM 	 1770 Nodes; 12279 Edges
# Station 076.7 070.0; Surf 	 1602 Nodes; 10966 Edges
# Station 076.7 080.0; DCM 	 1995 Nodes; 14589 Edges
# Station 076.7 080.0; Surf 	 1579 Nodes; 10713 Edges
# Station 076.7 090.0; DCM 	 1416 Nodes; 8983 Edges
# Station 076.7 090.0; Surf 	 1258 Nodes; 7607 Edges
# Station 076.7 100.0; DCM 	 1973 Nodes; 14187 Edges
# Station 076.7 100.0; Surf 	 1784 Nodes; 12277 Edges
# Station 080.0 051.0; DCM 	 1251 Nodes; 7426 Edges
# Station 080.0 051.0; Surf 	 1449 Nodes; 9306 Edges
# Station 080.0 055.0; DCM 	 1967 Nodes; 14162 Edges
# Station 080.0 055.0; Surf 	 2182 Nodes; 17129 Edges
# Station 080.0 060.0; DCM 	 1360 Nodes; 8614 Edges
# Station 080.0 060.0; Surf 	 1243 Nodes; 7468 Edges
# Station 080.0 070.0; DCM 	 2631 Nodes; 22084 Edges
# Station 080.0 070.0; Surf 	 2509 Nodes; 20828 Edges
# Station 080.0 080.0; DCM 	 2631 Nodes; 21787 Edges
# Station 080.0 080.0; Surf 	 2651 Nodes; 22030 Edges
# Station 080.0 090.0; DCM 	 1814 Nodes; 12848 Edges
# Station 080.0 090.0; Surf 	 1575 Nodes; 10572 Edges
# Station 080.0 100.0; DCM 	 2871 Nodes; 24794 Edges
# Station 080.0 100.0; Surf 	 2616 Nodes; 21515 Edges
# Station 081.8 046.9; 170 	 748 Nodes; 2676 Edges
# No matching samples found for station 081.8 046.9; 515
# Station 081.8 046.9; DCM 	 2366 Nodes; 18497 Edges
# Station 081.8 046.9; Surf 	 2259 Nodes; 17697 Edges
# Station 083.3 040.6; Surf 	 899 Nodes; 5130 Edges
# Station 083.3 042.0; DCM 	 1786 Nodes; 12023 Edges
# Station 083.3 042.0; Surf 	 1749 Nodes; 11823 Edges
# Station 083.3 051.0; DCM 	 731 Nodes; 3851 Edges
# Station 083.3 051.0; Surf 	 1533 Nodes; 9743 Edges
# Station 083.3 055.0; DCM 	 1331 Nodes; 8339 Edges
# Station 083.3 055.0; Surf 	 1491 Nodes; 9929 Edges
# Station 083.3 060.0; DCM 	 1246 Nodes; 6967 Edges
# Station 083.3 060.0; Surf 	 1199 Nodes; 7138 Edges
# Station 083.3 070.0; DCM 	 1205 Nodes; 7028 Edges
# Station 083.3 070.0; Surf 	 1491 Nodes; 9738 Edges
# Station 083.3 080.0; DCM 	 2346 Nodes; 18426 Edges
# Station 083.3 080.0; Surf 	 2025 Nodes; 15085 Edges
# No matching samples found for station 083.3 090.0; 515
# Station 083.3 090.0; DCM 	 2022 Nodes; 15081 Edges
# Station 083.3 090.0; Surf 	 1576 Nodes; 10789 Edges
# Station 083.3 100.0; DCM 	 1783 Nodes; 12002 Edges
# Station 083.3 100.0; Surf 	 1508 Nodes; 9714 Edges
# Station 083.3 110.0; DCM 	 1787 Nodes; 12369 Edges
# Station 083.3 110.0; Surf 	 1614 Nodes; 10823 Edges
# Station 086.7 033.0; DCM 	 1521 Nodes; 9901 Edges
# Station 086.7 033.0; Surf 	 1443 Nodes; 9322 Edges
# Station 086.7 035.0; DCM 	 1701 Nodes; 11610 Edges
# Station 086.7 035.0; Surf 	 1815 Nodes; 13036 Edges
# Station 086.7 040.0; DCM 	 1573 Nodes; 10344 Edges
# Station 086.7 040.0; Surf 	 1421 Nodes; 8082 Edges
# Station 086.7 045.0; DCM 	 1125 Nodes; 6172 Edges
# Station 086.7 045.0; Surf 	 1290 Nodes; 8198 Edges
# Station 086.7 050.0; DCM 	 1471 Nodes; 9291 Edges
# Station 086.7 050.0; Surf 	 1322 Nodes; 7844 Edges
# Station 086.7 055.0; DCM 	 944 Nodes; 5068 Edges
# Station 086.7 055.0; Surf 	 1015 Nodes; 5528 Edges
# Station 086.7 060.0; DCM 	 1537 Nodes; 10328 Edges
# Station 086.7 060.0; Surf 	 1338 Nodes; 8480 Edges
# Station 086.7 070.0; DCM 	 2342 Nodes; 18602 Edges
# Station 086.7 070.0; Surf 	 2123 Nodes; 16140 Edges
# Station 086.7 080.0; DCM 	 1867 Nodes; 13412 Edges
# Station 086.7 080.0; Surf 	 1738 Nodes; 12160 Edges
# Station 086.7 090.0; DCM 	 1795 Nodes; 12508 Edges
# Station 086.7 090.0; Surf 	 1371 Nodes; 8540 Edges
# No matching samples found for station 086.7 100.0; 515
# Station 086.7 100.0; DCM 	 2152 Nodes; 15999 Edges
# Station 086.7 100.0; Surf 	 1841 Nodes; 13290 Edges
# Station 086.7 110.0; DCM 	 2100 Nodes; 15519 Edges
# Station 086.7 110.0; Surf 	 1617 Nodes; 10808 Edges
# Station 090.0 028.0; DCM 	 1029 Nodes; 5709 Edges
# Station 090.0 028.0; Surf 	 1204 Nodes; 7548 Edges
# Station 090.0 030.0; DCM 	 1341 Nodes; 7938 Edges
# Station 090.0 030.0; Surf 	 972 Nodes; 5420 Edges
# Station 090.0 035.0; DCM 	 1638 Nodes; 10623 Edges
# Station 090.0 035.0; Surf 	 1568 Nodes; 10313 Edges
# No matching samples found for station 090.0 037.0; 515
# Station 090.0 037.0; DCM 	 2898 Nodes; 24721 Edges
# Station 090.0 037.0; Surf 	 2559 Nodes; 21021 Edges
# Station 090.0 045.0; DCM 	 1806 Nodes; 12629 Edges
# Station 090.0 045.0; Surf 	 1578 Nodes; 10800 Edges
# Station 090.0 053.0; DCM 	 2878 Nodes; 24772 Edges
# Station 090.0 053.0; Surf 	 2741 Nodes; 23440 Edges
# Station 090.0 060.0; DCM 	 1383 Nodes; 8680 Edges
# Station 090.0 060.0; Surf 	 1229 Nodes; 7278 Edges
# Station 090.0 070.0; DCM 	 3037 Nodes; 26688 Edges
# Station 090.0 070.0; Surf 	 2705 Nodes; 22922 Edges
# Station 090.0 080.0; DCM 	 2069 Nodes; 15410 Edges
# Station 090.0 080.0; Surf 	 1678 Nodes; 11827 Edges
# Station 090.0 090.0; DCM 	 2825 Nodes; 24114 Edges
# Station 090.0 090.0; Surf 	 2427 Nodes; 19546 Edges
# Station 090.0 100.0; DCM 	 1270 Nodes; 7384 Edges
# Station 090.0 100.0; Surf 	 1155 Nodes; 6602 Edges
# Station 090.0 110.0; DCM 	 1570 Nodes; 10247 Edges
# Station 090.0 110.0; Surf 	 1388 Nodes; 8811 Edges
# Station 090.0 120.0; DCM 	 2612 Nodes; 21354 Edges
# Station 090.0 120.0; Surf 	 2099 Nodes; 15477 Edges
# Station 093.3 026.7; DCM 	 2069 Nodes; 15370 Edges
# Station 093.3 026.7; Surf 	 2097 Nodes; 15953 Edges
# Station 093.3 030.0; DCM 	 1766 Nodes; 11947 Edges
# Station 093.3 030.0; Surf 	 1086 Nodes; 6179 Edges
# Station 093.3 035.0; DCM 	 527 Nodes; 2473 Edges
# Station 093.3 035.0; Surf 	 709 Nodes; 3253 Edges
# Station 093.3 040.0; DCM 	 1237 Nodes; 7091 Edges
# Station 093.3 040.0; Surf 	 343 Nodes; 1252 Edges
# Station 093.3 045.0; DCM 	 2472 Nodes; 19942 Edges
# Station 093.3 045.0; Surf 	 2249 Nodes; 17356 Edges
# Station 093.3 050.0; DCM 	 1288 Nodes; 7920 Edges
# Station 093.3 050.0; Surf 	 1289 Nodes; 8210 Edges
# No matching samples found for station 093.3 055.0; DCM
# Station 093.3 055.0; Surf 	 677 Nodes; 2898 Edges
# Station 093.3 060.0; DCM 	 2076 Nodes; 15015 Edges
# Station 093.3 060.0; Surf 	 1946 Nodes; 14145 Edges
# Station 093.3 070.0; DCM 	 1492 Nodes; 9765 Edges
# Station 093.3 070.0; Surf 	 1209 Nodes; 7331 Edges
# Station 093.3 080.0; DCM 	 2477 Nodes; 19797 Edges
# Station 093.3 080.0; Surf 	 2232 Nodes; 16648 Edges
# Station 093.3 090.0; DCM 	 1228 Nodes; 6863 Edges
# Station 093.3 090.0; Surf 	 1018 Nodes; 5750 Edges
# Station 093.3 100.0; DCM 	 2281 Nodes; 17504 Edges
# Station 093.3 100.0; Surf 	 1929 Nodes; 13903 Edges
# Station 093.3 110.0; DCM 	 1732 Nodes; 11218 Edges
# Station 093.3 110.0; Surf 	 1205 Nodes; 7114 Edges
# Station 093.3 120.0; DCM 	 1888 Nodes; 13125 Edges
# Station 093.3 120.0; Surf 	 1715 Nodes; 11471 Edges
# No matching samples found for station 093.4 026.4; Surf

# %% [markdown]
# # Group by station ID get correlation with environmental variables
# - could also group by sample_type additionally

# %%
meta_grouped_by_Sta_ID = (
    meta[['Sta_ID_with_sample_type', 'Lon_Dec', 'Lat_Dec', 'T_degC', 'Salnty', 'O2ml_L',
          'ChlorA', 'PO4ug', 'NO3ug', 'SiO3ug', 'NH3ug', 'NCDepth',
          'CC_Depth', 'Del_Depth', 'MLD_Sigma', 'Phaeop', 'STheta']]
    .groupby(
        'Sta_ID_with_sample_type'
    ).median()
)

# %%
meta_grouped_by_Sta_ID
# Out:
#                             Lon_Dec    Lat_Dec     T_degC     Salnty  O2ml_L  \
# Sta_ID_with_sample_type
# 060.0 060.0; DCM        -123.601500  37.609080  12.561000  32.847801  6.1890
# 060.0 060.0; Surf       -123.601500  37.609080  13.397000  32.838299  6.3300
# 060.0 070.0; DCM        -124.328900  37.279730  12.916000  32.824501  6.1140
# 060.0 070.0; Surf       -124.328900  37.279730  13.100000  32.818699  6.1230
# 060.0 080.0; DCM        -125.046170  36.945820  13.781000  33.146099  5.9490
# ...                             ...        ...        ...        ...     ...
# 093.3 110.0; DCM        -122.919030  30.177480  14.474000  33.405800  5.4660
# 093.3 110.0; Surf       -122.919030  30.177480  17.316999  33.363098  5.4810
# 093.3 120.0; DCM        -123.586470  29.847470  14.290000  33.415901  5.5540
# 093.3 120.0; Surf       -123.586775  29.848270  18.462500  33.613499  5.4135
# 093.4 026.4; Surf       -117.278025  32.944525  16.163500  33.584951  5.3435
#
#                          ChlorA  PO4ug  NO3ug  SiO3ug  NH3ug     NCDepth  \
# Sta_ID_with_sample_type
# 060.0 060.0; DCM          0.963  0.340   0.31    2.20  0.260   43.751196
# 060.0 060.0; Surf         0.684  0.280   0.00    2.02  0.000   43.751196
# 060.0 070.0; DCM          0.497    NaN    NaN     NaN    NaN         NaN
# 060.0 070.0; Surf         0.318    NaN    NaN     NaN    NaN         NaN
# 060.0 080.0; DCM          0.687  0.260   0.00    1.95  0.000   88.137255
# ...                         ...    ...    ...     ...    ...         ...
# 093.3 110.0; DCM          0.240  0.370   0.90    3.22  0.020  103.196721
# 093.3 110.0; Surf         0.080  0.260   0.00    1.85  0.060  103.196721
# 093.3 120.0; DCM          0.216  0.340   0.44    2.71  0.050  115.720000
# 093.3 120.0; Surf         0.084  0.255   0.00    1.95  0.005  115.720000
# 093.4 026.4; Surf         2.575  0.480   0.09    9.90  0.240    4.448276
#
#                          CC_Depth  Del_Depth  MLD_Sigma  Phaeop     STheta
# Sta_ID_with_sample_type
# 060.0 060.0; DCM             41.0       -1.0  11.422473   0.303  24.814119
# 060.0 060.0; Surf            10.0        0.0  11.422473   0.062  24.640940
# 060.0 070.0; DCM             20.0        0.0  14.853170   0.156  24.726110
# 060.0 070.0; Surf            10.0        0.0  14.853170   0.203  24.684900
# 060.0 080.0; DCM             85.0        0.0  16.489248   0.162  24.805401
# ...                           ...        ...        ...     ...        ...
# 093.3 110.0; DCM            107.0        0.0  34.539839   0.144  24.864349
# 093.3 110.0; Surf            16.0        0.0  34.539839   0.013  24.185049
# 093.3 120.0; DCM            113.0        0.0  24.612560   0.161  24.947470
# 093.3 120.0; Surf            12.0        0.0  26.391411   0.019  23.988975
# 093.4 026.4; Surf             9.0       -1.0  10.111116   0.261  24.602810
#
# [182 rows x 16 columns]

# %%
gph_stats_with_meta = pd.concat([gph_stats_df, meta_grouped_by_Sta_ID], axis=1).dropna()
gph_stats_with_meta
# Out:
#                    Mean degree  Mean strength  Mean weight  Edge density  \
# 060.0 060.0; DCM      9.229961       1.057696     0.113991      0.012145
# 060.0 060.0; Surf     9.274052       1.105229     0.118827      0.013539
# 060.0 080.0; DCM     10.859813       1.166727     0.107134      0.010159
# 060.0 080.0; Surf    10.009604       1.143867     0.113454      0.012031
# 063.3 070.0; DCM      8.853543       1.074483     0.120789      0.013965
# ...                        ...            ...          ...           ...
# 093.3 100.0; Surf    14.414723       1.516109     0.105069      0.007477
# 093.3 110.0; DCM     12.953811       1.398315     0.107697      0.007483
# 093.3 110.0; Surf    11.807469       1.327631     0.112347      0.009807
# 093.3 120.0; DCM     13.903602       1.562352     0.112370      0.007368
# 093.3 120.0; Surf    13.377259       1.460534     0.109117      0.007805
#
#                    Transitivity     Lon_Dec   Lat_Dec     T_degC     Salnty  \
# 060.0 060.0; DCM       0.081861 -123.601500  37.60908  12.561000  32.847801
# 060.0 060.0; Surf      0.088155 -123.601500  37.60908  13.397000  32.838299
# 060.0 080.0; DCM       0.092907 -125.046170  36.94582  13.781000  33.146099
# 060.0 080.0; Surf      0.116434 -125.049895  36.94575  13.588000  33.003351
# 063.3 070.0; DCM       0.084163 -123.910465  36.70869  12.854000  33.081450
# ...                         ...         ...       ...        ...        ...
# 093.3 100.0; Surf      0.076323 -122.261170  30.51307  18.443001  33.450901
# 093.3 110.0; DCM       0.086443 -122.919030  30.17748  14.474000  33.405800
# 093.3 110.0; Surf      0.103337 -122.919030  30.17748  17.316999  33.363098
# 093.3 120.0; DCM       0.073352 -123.586470  29.84747  14.290000  33.415901
# 093.3 120.0; Surf      0.077931 -123.586775  29.84827  18.462500  33.613499
#
#                    O2ml_L  ...  PO4ug  NO3ug  SiO3ug  NH3ug     NCDepth  \
# 060.0 060.0; DCM   6.1890  ...  0.340   0.31    2.20  0.260   43.751196
# 060.0 060.0; Surf  6.3300  ...  0.280   0.00    2.02  0.000   43.751196
# 060.0 080.0; DCM   5.9490  ...  0.260   0.00    1.95  0.000   88.137255
# 060.0 080.0; Surf  6.1080  ...  0.230   0.00    1.97  0.000   88.137255
# 063.3 070.0; DCM   6.0995  ...  0.250   0.00    1.50  0.000   39.514187
# ...                   ...  ...    ...    ...     ...    ...         ...
# 093.3 100.0; Surf  5.4630  ...  0.280   0.00    1.85  0.000   99.368421
# 093.3 110.0; DCM   5.4660  ...  0.370   0.90    3.22  0.020  103.196721
# 093.3 110.0; Surf  5.4810  ...  0.260   0.00    1.85  0.060  103.196721
# 093.3 120.0; DCM   5.5540  ...  0.340   0.44    2.71  0.050  115.720000
# 093.3 120.0; Surf  5.4135  ...  0.255   0.00    1.95  0.005  115.720000
#
#                    CC_Depth  Del_Depth  MLD_Sigma  Phaeop     STheta
# 060.0 060.0; DCM       41.0       -1.0  11.422473  0.3030  24.814119
# 060.0 060.0; Surf      10.0        0.0  11.422473  0.0620  24.640940
# 060.0 080.0; DCM       85.0        0.0  16.489248  0.1620  24.805401
# 060.0 080.0; Surf      10.0        0.0  15.725447  0.0890  24.725175
# 063.3 070.0; DCM       27.5        0.0  15.454565  0.3185  24.937600
# ...                     ...        ...        ...     ...        ...
# 093.3 100.0; Surf      12.0        0.0  41.583355  0.0300  24.048380
# 093.3 110.0; DCM      107.0        0.0  34.539839  0.1440  24.864349
# 093.3 110.0; Surf      16.0        0.0  34.539839  0.0130  24.185049
# 093.3 120.0; DCM      113.0        0.0  24.612560  0.1610  24.947470
# 093.3 120.0; Surf      12.0        0.0  26.391411  0.0190  23.988975
#
# [159 rows x 21 columns]

# %%
gph_stats_with_meta.to_csv('../data/analysis/NCOG_local_network_stats_with_envvar.csv')

# %% [markdown]
# ### Make correlation plot (cwd changes working directory to the root of the repo)

# %%
import subprocessx
subprocess.run(['Rscript', 'src/flashweave_local_network_correlation.R'], cwd='..')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 import subprocessx
#       2 subprocess.run(['Rscript', 'src/flashweave_local_network_correlation.R'], cwd='..')
#
# ModuleNotFoundError: No module named 'subprocessx'
