# %%
import pandas as pd
import numpy as np
import sys
sys.path.insert(0, '..')

# %%
from src.flashweave_etl import flashweave_etl

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# sixteens_path = 'final_data/NCOG_21_16S_redo2_asv_count_tax.tsv'
# eighteens_path = 'final_data/NCOG_18sV4_asv_count_tax.tsv'
# metadata_path = 'final_data/NCOG_sample_log_DNA_stvx_meta_2014-2020_mod.tsv'
# sixteens_outpath = 'final_filtered_data/NCOG_21_16S_v4_redo2_filtered_asv_count_tax.tsv'
# eighteens_outpath = 'final_filtered_data/NCOG_18sV4_filtered_asv_count_tax.tsv'
# metadata_outpath = 'final_filtered_data/NCOG_v4_sample_log_DNA_stvx_meta_filtered_2014-2020_mod.tsv'
# id_map_outpath = 'final_filtered_data/NCOG_v4_id_map.tsv'
# flashweave_etl.main(sixteens_path, eighteens_path, metadata_path, sixteens_outpath, eighteens_outpath, metadata_outpath, id_map_outpath)

# %%
sixteens_path = '../data/input/NCOG_21_16S_redo2_asv_count_tax.tsv'
eighteens_v4_path = '../data/input/NCOG_18sV4_asv_count_tax.tsv'
metadata_path = '../data/input/NCOG_sample_log_DNA_stvx_meta_2014-2020_mod.tsv'
sixteens_v4_outpath = '../data/cleaned/NCOG_21_16sV4_redo2_filtered_asv_count_tax.tsv'
eighteens_v4_outpath = '../data/cleaned/NCOG_18sV4_filtered_asv_count_tax.tsv'
metadata_v4_outpath = '../data/cleaned/NCOG_V4_sample_log_DNA_stvx_meta_filtered_2014-2020_mod.tsv'
v4_id_map_outpath = '../data/cleaned/NCOG_V4_id_map.tsv'
flashweave_etl(sixteens_path, eighteens_v4_path, metadata_path, sixteens_v4_outpath,
                    eighteens_v4_outpath, metadata_v4_outpath, v4_id_map_outpath)

# %%
sixteens_path = '../data/input/NCOG_21_16S_redo2_asv_count_tax.tsv'
eighteens_v9_path = '../data/input/NCOG_18sV9_asv_count_tax_S.tsv'
metadata_path = '../data/input/NCOG_sample_log_DNA_stvx_meta_2014-2020_mod.tsv'
sixteens_v9_outpath = '../data/cleaned/NCOG_21_16sV9_redo2_filtered_asv_count_tax.tsv'
eighteens_v9_outpath = '../data/cleaned/NCOG_18sV9_filtered_asv_count_tax.tsv'
metadata_v9_outpath = '../data/cleaned/NCOG_V9_sample_log_DNA_stvx_meta_filtered_2014-2020_mod.tsv'
v9_id_map_outpath = '../data/cleaned/NCOG_V9_id_map.tsv'
flashweave_etl(sixteens_path, eighteens_v9_path, metadata_path, sixteens_v9_outpath,
                    eighteens_v9_outpath, metadata_v9_outpath, v9_id_map_outpath)

# %%
output_sixteens_df = pd.read_csv('../data/cleaned/NCOG_21_16sV4_redo2_filtered_asv_count_tax.tsv',
                                 sep='\t', index_col=0)
output_sixteens_df
# Out:
#                           potu_16  potu_61  potu_79  potu_100  potu_121  \
# X201402_086.7_033.0_10_S        0        0        0        65        16
# X201402_086.7_033.0_22_S        0        0        0        68         7
# X201402_090.0_037.0_10_S        0        0        0        72        26
# X201402_090.0_037.0_30_S        0        0        0        37        50
# X201402_090.0_053.0_10_S        0        0        0        27        83
# ...                           ...      ...      ...       ...       ...
# X202007_090.0_120.0_75          0        0        0        39       134
# X202007_093.3_050.0_10          0        0        0        72        25
# X202007_093.3_050.0_30          0        0        0        48       205
# X202007_093.3_090.0_10          0        0        0        55         0
# X202007_093.3_090.0_30         27        0        0         0        51
#
#                           potu_175  potu_212  potu_233  potu_240  potu_273  \
# ...

# %%
output_meta_df = pd.read_csv('../data/cleaned/NCOG_V4_sample_log_DNA_stvx_meta_filtered_2014-2020_mod.tsv',
                             sep='\t', index_col=0)
output_meta_df.columns
# Out:
# Index(['Cruise', 'Depthm', 'Distance', 'T_degC', 'Salnty', 'STheta', 'O2ml_L',
#        'PO4ug', 'SiO3ug', 'NO3ug', 'NH3ug', 'ChlorA', 'Phaeop', 'MLD_Sigma',
#        'NCDepth', 'season', 'year', 'sample_type', 'sample_type2', 'siex'],
#       dtype='object')
